# %%
"""
# 🎯 Notebook 04 : Génération d'Offres d'Emploi

**Objectif** : Créer un dataset d'offres d'emploi pour matcher avec le CV

**Approche** : Dataset fictif mais réaliste
- 25 offres réparties en 5 catégories
- Stack techniques variées
- Différents niveaux (Junior, Mid, Senior)

**Catégories** :
1. ML Engineer (5 offres) - Match attendu avec votre CV : 60-70%
2. Data Scientist (5 offres) - Match attendu : 45-55%
3. Python Developer (5 offres) - Match attendu : 50-60%
4. DevOps Engineer (5 offres) - Match attendu : 40-50%
5. Frontend Developer (5 offres) - Match attendu : 15-25%
"""

# %%
# Imports
import sys
import json
from pathlib import Path
from datetime import datetime, timedelta
import random
from typing import List, Dict

# Ajouter le dossier racine
project_root = Path().absolute().parent
sys.path.insert(0, str(project_root))

print(f"📁 Projet : {project_root}")
print(f"📂 Notebooks : {Path().absolute()}")
print(f"✅ Imports terminés")
# Out:
# 📁 Projet : c:\Users\rober\OneDrive\Bureau\PFE
# 📂 Notebooks : c:\Users\rober\OneDrive\Bureau\PFE\notebooks
# ✅ Imports terminés

# %%
# Templates d'offres d'emploi par catégorie

JOB_TEMPLATES = {
    "ml_engineer": [
        {
            "title": "Junior ML Engineer",
            "company": "AI Startup Paris",
            "type": "CDI",
            "experience": "0-2 ans",
            "salary": "35-45K€",
            "description": """
Nous recherchons un Junior ML Engineer passionné pour rejoindre notre équipe R&D.

Responsabilités :
- Développer des modèles de Machine Learning (classification, régression)
- Entraîner et optimiser des réseaux de neurones avec PyTorch
- Déployer des modèles en production avec Docker
- Participer aux revues de code et à l'amélioration continue

Stack technique :
- Python, PyTorch, scikit-learn
- Docker, Git
- FastAPI pour les APIs
- PostgreSQL
            """,
            "requirements": [
                "Python (numpy, pandas, scikit-learn)",
                "Machine Learning basics (supervised learning)",
                "Git et GitHub",
                "Docker (notions de base)",
                "Anglais technique (lecture documentation)"
            ],
            "nice_to_have": [
                "PyTorch ou TensorFlow",
                "FastAPI ou Flask",
                "MLflow",
                "AWS ou GCP"
            ]
        },
        {
            "title": "ML Engineer - Computer Vision",
            "company": "VisionTech",
            "type": "CDI",
            "experience": "1-3 ans",
            "salary": "40-50K€",
            "description": """
Rejoignez notre équipe Computer Vision pour développer des solutions d'analyse d'images.

Missions :
- Développer des modèles de Computer Vision (détection d'objets, segmentation)
- Fine-tuner des modèles pré-entraînés (YOLO, ResNet)
- Optimiser les performances des modèles pour la production
- Collaborer avec l'équipe produit

Technologies :
- Python, PyTorch, OpenCV
- CNNs, Transfer Learning
- Docker, Kubernetes
- MLOps (MLflow, DVC)
            """,
            "requirements": [
                "Deep Learning (CNNs, architectures modernes)",
                "PyTorch ou TensorFlow",
                "Computer Vision (OpenCV, PIL)",
                "Python avancé",
                "Git, Docker"
            ],
            "nice_to_have": [
                "YOLO, Faster R-CNN",
                "Kubernetes",
                "CI/CD",
                "Cloud (AWS, Azure)"
            ]
        },
        {
            "title": "NLP Engineer",
            "company": "TextAI",
            "type": "CDI",
            "experience": "1-3 ans",
            "salary": "42-52K€",
            "description": """
Nous cherchons un NLP Engineer pour développer des solutions de traitement du langage naturel.

Projets :
- Développer des modèles de classification de texte
- Fine-tuner des LLMs (BERT, GPT)
- Créer des systèmes de question-answering
- Implémenter des pipelines NLP en production

Stack :
- Python, HuggingFace Transformers
- spaCy, NLTK
- PyTorch
- FastAPI, Docker
- Elasticsearch
            """,
            "requirements": [
                "NLP (tokenization, embeddings, transformers)",
                "HuggingFace Transformers",
                "PyTorch",
                "Python (pandas, numpy)",
                "APIs RESTful"
            ],
            "nice_to_have": [
                "Fine-tuning LLMs",
                "spaCy",
                "Vector databases (Pinecone, Weaviate)",
                "Kubernetes"
            ]
        },
        {
            "title": "MLOps Engineer",
            "company": "DataCorp",
            "type": "CDI",
            "experience": "2-4 ans",
            "salary": "45-55K€",
            "description": """
Rejoignez notre équipe MLOps pour industrialiser le déploiement de modèles ML.

Responsabilités :
- Créer des pipelines CI/CD pour modèles ML
- Déployer des modèles en production (Docker, Kubernetes)
- Monitorer les performances des modèles
- Optimiser les temps d'inférence

Technologies :
- Python, Docker, Kubernetes
- MLflow, Kubeflow
- GitLab CI/CD
- Prometheus, Grafana
- AWS/GCP
            """,
            "requirements": [
                "MLOps (CI/CD pour ML)",
                "Docker, Kubernetes",
                "Python",
                "Cloud (AWS ou GCP)",
                "Git, GitLab/GitHub Actions"
            ],
            "nice_to_have": [
                "MLflow, Kubeflow",
                "Terraform",
                "Monitoring (Prometheus)",
                "FastAPI"
            ]
        },
        {
            "title": "Senior ML Engineer",
            "company": "BigTech France",
            "type": "CDI",
            "experience": "3-5 ans",
            "salary": "55-70K€",
            "description": """
Nous recherchons un Senior ML Engineer pour mener des projets ML stratégiques.

Missions :
- Architecturer des solutions ML scalables
- Encadrer des juniors
- Participer aux décisions techniques
- Optimiser les modèles pour la production

Stack technique :
- Python, PyTorch/TensorFlow
- Kubernetes, Helm
- AWS (SageMaker, Lambda, S3)
- Spark pour Big Data
- MLflow, DVC
            """,
            "requirements": [
                "5+ ans en Machine Learning",
                "Deep Learning avancé",
                "MLOps et architecture",
                "Kubernetes en production",
                "Leadership technique"
            ],
            "nice_to_have": [
                "Publications scientifiques",
                "Contributions open-source",
                "Spark, Big Data",
                "Plusieurs projets ML en production"
            ]
        }
    ],
    
    "data_scientist": [
        {
            "title": "Data Scientist Junior",
            "company": "Analytics Pro",
            "type": "CDI",
            "experience": "0-2 ans",
            "salary": "35-45K€",
            "description": """
Rejoignez notre équipe Data Science pour analyser des données et créer des modèles prédictifs.

Missions :
- Analyser des datasets et créer des visualisations
- Développer des modèles prédictifs (régression, classification)
- Collaborer avec les équipes métier
- Présenter les résultats aux stakeholders

Outils :
- Python (pandas, numpy, matplotlib)
- Jupyter Notebooks
- scikit-learn
- SQL
- Git
            """,
            "requirements": [
                "Python (pandas, numpy, matplotlib)",
                "Machine Learning (scikit-learn)",
                "SQL",
                "Statistiques",
                "Communication (présentation de résultats)"
            ],
            "nice_to_have": [
                "PowerBI ou Tableau",
                "Feature engineering",
                "Time series analysis",
                "A/B testing"
            ]
        },
        {
            "title": "Data Scientist - Marketing",
            "company": "MarketingTech",
            "type": "CDI",
            "experience": "1-3 ans",
            "salary": "40-50K€",
            "description": """
Nous cherchons un Data Scientist pour optimiser nos campagnes marketing.

Projets :
- Modèles de prédiction de churn
- Segmentation clients (clustering)
- Analyse de l'attribution marketing
- Recommandation de produits

Stack :
- Python, R
- scikit-learn, XGBoost
- SQL (PostgreSQL)
- Tableau/PowerBI
- Git
            """,
            "requirements": [
                "Python et/ou R",
                "Machine Learning (classification, clustering)",
                "SQL avancé",
                "Statistiques et A/B testing",
                "Visualisation de données"
            ],
            "nice_to_have": [
                "Marketing analytics",
                "Google Analytics",
                "Système de recommandation",
                "Big Data (Spark)"
            ]
        },
        {
            "title": "Data Scientist - Finance",
            "company": "FinTech Solutions",
            "type": "CDI",
            "experience": "2-4 ans",
            "salary": "45-60K€",
            "description": """
Rejoignez notre équipe Data Science pour développer des modèles de risque financier.

Responsabilités :
- Modèles de scoring de crédit
- Détection de fraude
- Prédiction de séries temporelles
- Reporting réglementaire

Technologies :
- Python, scikit-learn, XGBoost
- Time series (ARIMA, Prophet)
- SQL, PySpark
- Git, Docker
            """,
            "requirements": [
                "Machine Learning (classification, regression)",
                "Time series analysis",
                "Python (pandas, scikit-learn)",
                "SQL",
                "Statistiques avancées"
            ],
            "nice_to_have": [
                "Finance/Risk management",
                "PySpark",
                "Réglementation RGPD",
                "Explainability (SHAP)"
            ]
        },
        {
            "title": "Lead Data Scientist",
            "company": "DataLab",
            "type": "CDI",
            "experience": "3-5 ans",
            "salary": "55-70K€",
            "description": """
Nous recherchons un Lead Data Scientist pour encadrer une équipe de 3-5 personnes.

Missions :
- Définir la stratégie data science
- Encadrer et mentorer l'équipe
- Architecturer les solutions ML
- Interface avec les équipes métier

Stack :
- Python, R
- scikit-learn, XGBoost, LightGBM
- MLflow, DVC
- Cloud (AWS/GCP)
- Airflow pour orchestration
            """,
            "requirements": [
                "5+ ans en Data Science",
                "Leadership et encadrement",
                "ML avancé (ensembles, deep learning)",
                "MLOps",
                "Communication avec stakeholders"
            ],
            "nice_to_have": [
                "PhD en ML/Stats",
                "Publications",
                "Big Data (Spark)",
                "Architecture cloud"
            ]
        },
        {
            "title": "Data Scientist - HealthTech",
            "company": "MedAI",
            "type": "CDI",
            "experience": "2-4 ans",
            "salary": "48-58K€",
            "description": """
Rejoignez notre mission d'améliorer la santé par l'IA.

Projets :
- Analyse d'images médicales
- Prédiction de pathologies
- Optimisation de parcours patients
- Conformité RGPD et données de santé

Technologies :
- Python, PyTorch
- Computer Vision (medical imaging)
- scikit-learn
- PostgreSQL
- Docker
            """,
            "requirements": [
                "Machine Learning et/ou Deep Learning",
                "Python avancé",
                "Statistiques",
                "Éthique et RGPD",
                "Communication avec médecins"
            ],
            "nice_to_have": [
                "Background médical/biologie",
                "Computer Vision",
                "Clinical trials analysis",
                "Explainable AI"
            ]
        }
    ],
    
    "python_developer": [
        {
            "title": "Python Developer Junior",
            "company": "WebDev Studio",
            "type": "CDI",
            "experience": "0-2 ans",
            "salary": "32-42K€",
            "description": """
Nous recherchons un développeur Python junior pour rejoindre notre équipe backend.

Missions :
- Développer des APIs RESTful avec FastAPI
- Intégrer des bases de données (PostgreSQL)
- Écrire des tests unitaires
- Participer aux code reviews

Stack :
- Python 3.10+
- FastAPI
- PostgreSQL
- Docker
- Git
            """,
            "requirements": [
                "Python (bonnes pratiques)",
                "APIs RESTful",
                "SQL",
                "Git",
                "Tests unitaires (pytest)"
            ],
            "nice_to_have": [
                "FastAPI",
                "Docker",
                "CI/CD",
                "Redis"
            ]
        },
        {
            "title": "Backend Developer Python",
            "company": "SaaS Company",
            "type": "CDI",
            "experience": "1-3 ans",
            "salary": "38-48K€",
            "description": """
Rejoignez notre équipe pour développer notre plateforme SaaS.

Responsabilités :
- Développer des microservices Python
- Optimiser les performances
- Intégrer des APIs tierces
- Maintenir la qualité du code

Technologies :
- Python, FastAPI/Flask
- PostgreSQL, Redis
- RabbitMQ ou Kafka
- Docker, Kubernetes
- AWS
            """,
            "requirements": [
                "Python avancé",
                "FastAPI ou Flask",
                "Bases de données (SQL et NoSQL)",
                "Docker",
                "APIs RESTful et GraphQL"
            ],
            "nice_to_have": [
                "Microservices",
                "Message queues (RabbitMQ)",
                "Kubernetes",
                "AWS/GCP"
            ]
        },
        {
            "title": "Python Developer - Data Engineering",
            "company": "BigData Corp",
            "type": "CDI",
            "experience": "2-4 ans",
            "salary": "42-55K€",
            "description": """
Nous cherchons un développeur Python pour construire des pipelines de données.

Projets :
- Développer des ETL en Python
- Traiter des volumes de données importants
- Optimiser les performances des pipelines
- Déployer sur le cloud

Stack :
- Python (pandas, polars)
- Airflow
- Spark (PySpark)
- PostgreSQL, MongoDB
- Docker, Kubernetes
- AWS (S3, Lambda, Glue)
            """,
            "requirements": [
                "Python (pandas, numpy)",
                "ETL et data pipelines",
                "SQL avancé",
                "Airflow",
                "Cloud (AWS ou GCP)"
            ],
            "nice_to_have": [
                "PySpark",
                "Streaming (Kafka)",
                "Data modeling",
                "DBT"
            ]
        },
        {
            "title": "Full Stack Developer Python/React",
            "company": "TechStartup",
            "type": "CDI",
            "experience": "2-4 ans",
            "salary": "45-55K€",
            "description": """
Rejoignez notre startup pour développer notre produit full-stack.

Responsabilités :
- Backend Python (FastAPI)
- Frontend React
- Bases de données
- Déploiement cloud

Stack :
- Python, FastAPI
- React, TypeScript
- PostgreSQL
- Docker, AWS
- Git, CI/CD
            """,
            "requirements": [
                "Python (FastAPI ou Flask)",
                "React et TypeScript",
                "SQL",
                "RESTful APIs",
                "Git"
            ],
            "nice_to_have": [
                "Next.js",
                "GraphQL",
                "Docker/Kubernetes",
                "AWS"
            ]
        },
        {
            "title": "Senior Python Developer",
            "company": "Enterprise Tech",
            "type": "CDI",
            "experience": "4-6 ans",
            "salary": "55-70K€",
            "description": """
Nous recherchons un Senior Python Developer pour mener des projets stratégiques.

Missions :
- Architecturer des applications Python scalables
- Mentorer des développeurs juniors
- Optimiser les performances
- Définir les standards de code

Technologies :
- Python 3.11+
- FastAPI, Django
- PostgreSQL, MongoDB, Redis
- Microservices
- Kubernetes, Helm
- CI/CD avancé
            """,
            "requirements": [
                "6+ ans en Python",
                "Architecture logicielle",
                "Microservices",
                "Leadership technique",
                "Performance optimization"
            ],
            "nice_to_have": [
                "Contributions open-source",
                "Conférences/talks",
                "Multiple frameworks",
                "Security best practices"
            ]
        }
    ],
    
    "devops_engineer": [
        {
            "title": "DevOps Engineer Junior",
            "company": "CloudOps",
            "type": "CDI",
            "experience": "0-2 ans",
            "salary": "35-45K€",
            "description": """
Rejoignez notre équipe DevOps pour automatiser le déploiement d'applications.

Missions :
- Créer des pipelines CI/CD
- Déployer des applications avec Docker
- Gérer l'infrastructure cloud (AWS)
- Monitorer les applications

Outils :
- Docker, Docker Compose
- GitLab CI/CD ou GitHub Actions
- AWS (EC2, S3, RDS)
- Linux
- Git
            """,
            "requirements": [
                "Docker et containerisation",
                "CI/CD (GitLab ou GitHub Actions)",
                "Linux (bash scripting)",
                "Git",
                "Cloud basics (AWS ou Azure)"
            ],
            "nice_to_have": [
                "Kubernetes",
                "Terraform",
                "Ansible",
                "Python scripting"
            ]
        },
        {
            "title": "DevOps Engineer - Kubernetes",
            "company": "ContainerTech",
            "type": "CDI",
            "experience": "2-4 ans",
            "salary": "45-55K€",
            "description": """
Nous cherchons un DevOps spécialisé Kubernetes pour gérer notre infrastructure.

Responsabilités :
- Gérer des clusters Kubernetes
- Déployer des applications (Helm charts)
- Monitorer et optimiser les ressources
- Automatiser avec Terraform

Stack :
- Kubernetes, Helm
- Docker
- Terraform, Ansible
- AWS EKS ou GCP GKE
- Prometheus, Grafana
- ArgoCD
            """,
            "requirements": [
                "Kubernetes (déploiements, services, ingress)",
                "Docker avancé",
                "Terraform ou Ansible",
                "Cloud (AWS, GCP ou Azure)",
                "Monitoring (Prometheus)"
            ],
            "nice_to_have": [
                "Helm charts",
                "GitOps (ArgoCD, Flux)",
                "Service mesh (Istio)",
                "CKA certification"
            ]
        },
        {
            "title": "SRE Engineer",
            "company": "ScaleOps",
            "type": "CDI",
            "experience": "3-5 ans",
            "salary": "50-65K€",
            "description": """
Rejoignez notre équipe SRE pour garantir la fiabilité de nos services.

Missions :
- Définir et suivre les SLOs
- Automatiser les tâches opérationnelles
- Répondre aux incidents
- Optimiser les performances

Technologies :
- Kubernetes, Docker
- Terraform, Ansible
- Python, Go
- Prometheus, Grafana, ELK
- Cloud (multi-cloud)
            """,
            "requirements": [
                "SRE ou DevOps expérimenté",
                "Kubernetes en production",
                "Scripting (Python ou Go)",
                "Monitoring avancé",
                "Incident management"
            ],
            "nice_to_have": [
                "On-call experience",
                "Chaos engineering",
                "Multi-cloud",
                "Security (DevSecOps)"
            ]
        },
        {
            "title": "Platform Engineer",
            "company": "InfraTech",
            "type": "CDI",
            "experience": "3-5 ans",
            "salary": "52-68K€",
            "description": """
Nous recherchons un Platform Engineer pour construire notre plateforme interne.

Projets :
- Créer une plateforme self-service pour les devs
- Automatiser les déploiements
- Gérer l'infrastructure as code
- Améliorer la developer experience

Stack :
- Kubernetes, Helm
- Terraform, Pulumi
- GitLab CI/CD
- ArgoCD
- Internal Developer Platform (Backstage)
            """,
            "requirements": [
                "Kubernetes avancé",
                "Infrastructure as Code (Terraform)",
                "CI/CD",
                "Developer experience",
                "Scripting (Python, Bash, Go)"
            ],
            "nice_to_have": [
                "Backstage ou similaire",
                "API design",
                "Multi-tenancy",
                "FinOps"
            ]
        },
        {
            "title": "Lead DevOps Engineer",
            "company": "BigCorp",
            "type": "CDI",
            "experience": "5-7 ans",
            "salary": "60-80K€",
            "description": """
Nous recherchons un Lead DevOps pour diriger notre transformation cloud.

Responsabilités :
- Définir la stratégie DevOps
- Encadrer une équipe de 5+ engineers
- Architecturer l'infrastructure
- Budget et optimisation des coûts cloud

Technologies :
- Multi-cloud (AWS, GCP, Azure)
- Kubernetes, Helm, ArgoCD
- Terraform
- Security et compliance
- FinOps
            """,
            "requirements": [
                "7+ ans en DevOps/SRE",
                "Leadership d'équipe",
                "Architecture cloud",
                "Security et compliance",
                "Budget management"
            ],
            "nice_to_have": [
                "Certifications cloud",
                "Talks/conférences",
                "Open-source contributions",
                "FinOps certified"
            ]
        }
    ],
    
    "frontend_developer": [
        {
            "title": "Frontend Developer Junior",
            "company": "WebAgency",
            "type": "CDI",
            "experience": "0-2 ans",
            "salary": "30-40K€",
            "description": """
Nous recherchons un développeur frontend junior pour créer des interfaces web modernes.

Missions :
- Développer des interfaces React
- Intégrer des maquettes Figma
- Optimiser les performances
- Collaborer avec les designers

Stack :
- React, JavaScript
- HTML5, CSS3, SASS
- Git
- Responsive design
            """,
            "requirements": [
                "React basics",
                "JavaScript (ES6+)",
                "HTML5, CSS3",
                "Git",
                "Responsive design"
            ],
            "nice_to_have": [
                "TypeScript",
                "Next.js",
                "Tailwind CSS",
                "Testing (Jest)"
            ]
        },
        {
            "title": "React Developer",
            "company": "SaaS Startup",
            "type": "CDI",
            "experience": "1-3 ans",
            "salary": "38-48K€",
            "description": """
Rejoignez notre équipe pour développer notre application SaaS en React.

Responsabilités :
- Développer des composants React réutilisables
- Gérer l'état avec Redux/Zustand
- Intégrer des APIs RESTful
- Optimiser les performances

Technologies :
- React, TypeScript
- Redux ou Zustand
- React Query
- Tailwind CSS
- Jest, React Testing Library
            """,
            "requirements": [
                "React avancé",
                "TypeScript",
                "State management (Redux/Zustand)",
                "APIs RESTful",
                "Tests unitaires"
            ],
            "nice_to_have": [
                "Next.js",
                "GraphQL",
                "Webpack/Vite",
                "CI/CD"
            ]
        },
        {
            "title": "Frontend Developer - Vue.js",
            "company": "TechCorp",
            "type": "CDI",
            "experience": "2-4 ans",
            "salary": "40-50K€",
            "description": """
Nous cherchons un développeur Vue.js pour notre plateforme B2B.

Projets :
- Développer des interfaces Vue.js 3
- Créer des composants Vuetify
- Intégrer des APIs GraphQL
- Optimiser les bundles

Stack :
- Vue.js 3, Composition API
- Vuetify ou Quasar
- Pinia
- GraphQL (Apollo Client)
- Vite
            """,
            "requirements": [
                "Vue.js 3 (Composition API)",
                "JavaScript/TypeScript",
                "State management (Pinia)",
                "APIs (REST ou GraphQL)",
                "Build tools (Vite, Webpack)"
            ],
            "nice_to_have": [
                "Nuxt.js",
                "Testing (Vitest)",
                "UI libraries (Vuetify)",
                "Docker"
            ]
        },
        {
            "title": "Full Stack JavaScript Developer",
            "company": "Digital Agency",
            "type": "CDI",
            "experience": "2-4 ans",
            "salary": "42-55K€",
            "description": """
Rejoignez notre agence pour développer des projets web full-stack.

Responsabilités :
- Frontend React/Next.js
- Backend Node.js/Express
- Bases de données MongoDB
- Déploiement Vercel/Netlify

Technologies :
- React, Next.js
- Node.js, Express
- MongoDB, Prisma
- TypeScript
- Vercel, AWS
            """,
            "requirements": [
                "React et Next.js",
                "Node.js et Express",
                "MongoDB ou PostgreSQL",
                "TypeScript",
                "APIs RESTful"
            ],
            "nice_to_have": [
                "GraphQL",
                "Prisma ORM",
                "Serverless",
                "Docker"
            ]
        },
        {
            "title": "Lead Frontend Developer",
            "company": "Enterprise UI",
            "type": "CDI",
            "experience": "4-6 ans",
            "salary": "55-70K€",
            "description": """
Nous recherchons un Lead Frontend pour encadrer notre équipe UI.

Missions :
- Architecturer les applications frontend
- Définir les standards de code
- Mentorer l'équipe (3-5 devs)
- Optimiser les performances

Stack :
- React, TypeScript
- Micro-frontends
- Monorepo (Nx, Turborepo)
- Testing avancé
- CI/CD
            """,
            "requirements": [
                "6+ ans en frontend",
                "Architecture frontend",
                "Leadership technique",
                "Performance optimization",
                "Micro-frontends"
            ],
            "nice_to_have": [
                "Monorepo expertise",
                "Web Vitals expert",
                "Accessibility (WCAG)",
                "Design systems"
            ]
        }
    ]
}

print("✅ Templates chargés")
print(f"   • ML Engineer : {len(JOB_TEMPLATES['ml_engineer'])} offres")
print(f"   • Data Scientist : {len(JOB_TEMPLATES['data_scientist'])} offres")
print(f"   • Python Developer : {len(JOB_TEMPLATES['python_developer'])} offres")
print(f"   • DevOps Engineer : {len(JOB_TEMPLATES['devops_engineer'])} offres")
print(f"   • Frontend Developer : {len(JOB_TEMPLATES['frontend_developer'])} offres")
print(f"\n📊 TOTAL : {sum(len(v) for v in JOB_TEMPLATES.values())} offres")
# Out:
# ✅ Templates chargés
#    • ML Engineer : 5 offres
#    • Data Scientist : 5 offres
#    • Python Developer : 5 offres
#    • DevOps Engineer : 5 offres
#    • Frontend Developer : 5 offres
#
# 📊 TOTAL : 25 offres

# %%
def generate_job_posting(template: Dict, job_id: int, category: str) -> Dict:
    """
    Générer une offre d'emploi complète à partir d'un template
    
    Args:
        template: Template d'offre
        job_id: ID unique de l'offre
        category: Catégorie (ml_engineer, data_scientist, etc.)
    
    Returns:
        Dict avec l'offre complète
    """
    # Générer une date de publication aléatoire (entre 1 et 30 jours)
    days_ago = random.randint(1, 30)
    posted_date = (datetime.now() - timedelta(days=days_ago)).strftime("%Y-%m-%d")
    
    # Générer des localisations variées
    locations = [
        "Paris, France",
        "Lyon, France",
        "Toulouse, France",
        "Remote France",
        "Paris (Hybrid)",
        "Bordeaux, France",
        "Nantes, France"
    ]
    
    job_posting = {
        "job_id": f"job_{job_id:03d}",
        "category": category,
        "title": template["title"],
        "company": template["company"],
        "location": random.choice(locations),
        "type": template["type"],
        "experience": template["experience"],
        "salary": template["salary"],
        "description": template["description"].strip(),
        "requirements": template["requirements"],
        "nice_to_have": template["nice_to_have"],
        "posted_date": posted_date,
        "url": f"https://example-jobs.com/{job_id}",
        "remote_ok": "Remote" in random.choice(locations) or random.random() > 0.7,
        "applicants": random.randint(5, 150)
    }
    
    return job_posting


# Test de la fonction
print("\n🧪 TEST : Génération d'une offre")
print("=" * 60)

test_job = generate_job_posting(
    JOB_TEMPLATES["ml_engineer"][0],
    job_id=1,
    category="ml_engineer"
)

print(f"✅ Offre générée :")
print(f"   • ID : {test_job['job_id']}")
print(f"   • Titre : {test_job['title']}")
print(f"   • Entreprise : {test_job['company']}")
print(f"   • Localisation : {test_job['location']}")
print(f"   • Expérience : {test_job['experience']}")
print(f"   • Salaire : {test_job['salary']}")
print(f"   • Remote : {'Oui' if test_job['remote_ok'] else 'Non'}")
print(f"   • Postée le : {test_job['posted_date']}")
print(f"   • Candidatures : {test_job['applicants']}")
# Out:
# 🧪 TEST : Génération d'une offre
# ...
# ✅ Offre générée :
#    • ID : job_001
#    • Titre : Junior ML Engineer
#    • Entreprise : AI Startup Paris
#    • Localisation : Remote France
#    • Expérience : 0-2 ans
#    • Salaire : 35-45K€
#    • Remote : Oui
#    • Postée le : 2025-12-26
#    • Candidatures : 80

# %%
# Générer toutes les offres
print("\n🔧 GÉNÉRATION DU DATASET COMPLET")
print("=" * 60)

all_jobs = []
job_id = 1

for category, templates in JOB_TEMPLATES.items():
    print(f"\n📂 Catégorie : {category}")
    
    for template in templates:
        job = generate_job_posting(template, job_id, category)
        all_jobs.append(job)
        
        print(f"   {job_id}. {job['title']} - {job['company']}")
        
        job_id += 1

print(f"\n✅ Dataset généré : {len(all_jobs)} offres")
print(f"   • ML Engineer : {len([j for j in all_jobs if j['category'] == 'ml_engineer'])}")
print(f"   • Data Scientist : {len([j for j in all_jobs if j['category'] == 'data_scientist'])}")
print(f"   • Python Developer : {len([j for j in all_jobs if j['category'] == 'python_developer'])}")
print(f"   • DevOps Engineer : {len([j for j in all_jobs if j['category'] == 'devops_engineer'])}")
print(f"   • Frontend Developer : {len([j for j in all_jobs if j['category'] == 'frontend_developer'])}")
# Out:
# 🔧 GÉNÉRATION DU DATASET COMPLET
# ...
#
# 📂 Catégorie : ml_engineer
#    1. Junior ML Engineer - AI Startup Paris
#    2. ML Engineer - Computer Vision - VisionTech
#    3. NLP Engineer - TextAI
#    4. MLOps Engineer - DataCorp
#    5. Senior ML Engineer - BigTech France
#
# 📂 Catégorie : data_scientist
#    6. Data Scientist Junior - Analytics Pro
#    7. Data Scientist - Marketing - MarketingTech
#    8. Data Scientist - Finance - FinTech Solutions
#    9. Lead Data Scientist - DataLab
#    10. Data Scientist - HealthTech - MedAI
#
# 📂 Catégorie : python_developer
#    11. Python Developer Junior - WebDev Studio
#    12. Backend Developer Python - SaaS Company
#    13. Python Developer - Data Engineering - BigData Corp
#    14. Full Stack Developer Python/React - TechStartup
#    15. Senior Python Developer - Enterprise Tech
#
# 📂 Catégorie : devops_engineer
#    16. DevOps Engineer Junior - CloudOps
#    17. DevOps Engineer - Kubernetes - ContainerTech
#    18. SRE Engineer - ScaleOps
# ...

# %%
# Analyser le dataset
print("\n📊 ANALYSE DU DATASET")
print("=" * 60)

# Statistiques générales
print(f"\n1️⃣ STATISTIQUES GÉNÉRALES")
print(f"   • Nombre total d'offres : {len(all_jobs)}")
print(f"   • Offres remote : {len([j for j in all_jobs if j['remote_ok']])} ({len([j for j in all_jobs if j['remote_ok']]) / len(all_jobs) * 100:.1f}%)")

# Distribution par niveau d'expérience
exp_levels = {}
for job in all_jobs:
    exp = job['experience']
    exp_levels[exp] = exp_levels.get(exp, 0) + 1

print(f"\n2️⃣ RÉPARTITION PAR EXPÉRIENCE")
for exp, count in sorted(exp_levels.items()):
    print(f"   • {exp:15s} : {count:2d} offres")

# Distribution par catégorie
print(f"\n3️⃣ RÉPARTITION PAR CATÉGORIE")
categories = {}
for job in all_jobs:
    cat = job['category'].replace('_', ' ').title()
    categories[cat] = categories.get(cat, 0) + 1

for cat, count in sorted(categories.items(), key=lambda x: x[1], reverse=True):
    bar = "█" * count
    print(f"   • {cat:20s} : {bar} {count}")

# Échantillon d'offres
print(f"\n4️⃣ ÉCHANTILLON D'OFFRES (5 premières)")
print("-" * 60)
for i, job in enumerate(all_jobs[:5], 1):
    print(f"{i}. {job['title']}")
    print(f"   Entreprise : {job['company']}")
    print(f"   Localisation : {job['location']}")
    print(f"   Expérience : {job['experience']}")
    print(f"   Salaire : {job['salary']}")
    print(f"   Compétences : {', '.join(job['requirements'][:3])}...")
    print()
# Out:
# 📊 ANALYSE DU DATASET
# ...
#
# 1️⃣ STATISTIQUES GÉNÉRALES
#    • Nombre total d'offres : 25
#    • Offres remote : 8 (32.0%)
#
# 2️⃣ RÉPARTITION PAR EXPÉRIENCE
#    • 0-2 ans         :  5 offres
#    • 1-3 ans         :  5 offres
#    • 2-4 ans         :  8 offres
#    • 3-5 ans         :  4 offres
#    • 4-6 ans         :  2 offres
#    • 5-7 ans         :  1 offres
#
# 3️⃣ RÉPARTITION PAR CATÉGORIE
#    • Ml Engineer          : █████ 5
#    • Data Scientist       : █████ 5
#    • Python Developer     : █████ 5
#    • Devops Engineer      : █████ 5
#    • Frontend Developer   : █████ 5
#
# 4️⃣ ÉCHANTILLON D'OFFRES (5 premières)
# ------------------------------------------------------------
# 1. Junior ML Engineer
#    Entreprise : AI Startup Paris
#    Localisation : Toulouse, France
#    Expérience : 0-2 ans
#    Salaire : 35-45K€
#    Compétences : Python (numpy, pandas, scikit-learn), Machine Learning basics (supervised learning), Git et GitHub...
#
# 2. ML Engineer - Computer Vision
# ...

# %%
# Sauvegarder le dataset
print("\n💾 SAUVEGARDE DU DATASET")
print("=" * 60)

# Créer le dossier data/jobs
jobs_dir = project_root / "data" / "jobs"
jobs_dir.mkdir(parents=True, exist_ok=True)

# Sauvegarder le dataset complet
output_path = jobs_dir / "jobs_dataset.json"

dataset = {
    "metadata": {
        "total_jobs": len(all_jobs),
        "generated_date": datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
        "categories": list(JOB_TEMPLATES.keys()),
        "description": "Dataset d'offres d'emploi fictives pour matching CV"
    },
    "jobs": all_jobs
}

with open(output_path, 'w', encoding='utf-8') as f:
    json.dump(dataset, f, indent=2, ensure_ascii=False)

print(f"✅ Dataset sauvegardé : {output_path}")
print(f"   • Taille : {output_path.stat().st_size / 1024:.1f} KB")

# Sauvegarder par catégorie (optionnel)
print(f"\n💾 Sauvegarde par catégorie...")

for category in JOB_TEMPLATES.keys():
    category_jobs = [j for j in all_jobs if j['category'] == category]
    
    category_path = jobs_dir / f"jobs_{category}.json"
    
    with open(category_path, 'w', encoding='utf-8') as f:
        json.dump({
            "category": category,
            "total": len(category_jobs),
            "jobs": category_jobs
        }, f, indent=2, ensure_ascii=False)
    
    print(f"   ✅ {category:20s} : {len(category_jobs)} offres → {category_path.name}")

print(f"\n✅ Génération terminée avec succès !")
print(f"\n📂 Fichiers créés dans : {jobs_dir}")
print(f"   • jobs_dataset.json (dataset complet)")
print(f"   • jobs_ml_engineer.json")
print(f"   • jobs_data_scientist.json")
print(f"   • jobs_python_developer.json")
print(f"   • jobs_devops_engineer.json")
print(f"   • jobs_frontend_developer.json")
# Out:
# 💾 SAUVEGARDE DU DATASET
# ...
# ✅ Dataset sauvegardé : c:\Users\rober\OneDrive\Bureau\PFE\data\jobs\jobs_dataset.json
#    • Taille : 28.2 KB
#
# 💾 Sauvegarde par catégorie...
#    ✅ ml_engineer          : 5 offres → jobs_ml_engineer.json
#    ✅ data_scientist       : 5 offres → jobs_data_scientist.json
#    ✅ python_developer     : 5 offres → jobs_python_developer.json
#    ✅ devops_engineer      : 5 offres → jobs_devops_engineer.json
#    ✅ frontend_developer   : 5 offres → jobs_frontend_developer.json
#
# ✅ Génération terminée avec succès !
#
# 📂 Fichiers créés dans : c:\Users\rober\OneDrive\Bureau\PFE\data\jobs
#    • jobs_dataset.json (dataset complet)
#    • jobs_ml_engineer.json
#    • jobs_data_scientist.json
#    • jobs_python_developer.json
#    • jobs_devops_engineer.json
#    • jobs_frontend_developer.json

# %%
# Vérifier que tout est OK
print("\n✅ VÉRIFICATION FINALE")
print("=" * 60)

# Vérifier que les fichiers existent
jobs_dir = project_root / "data" / "jobs"

if (jobs_dir / "jobs_dataset.json").exists():
    print("✅ jobs_dataset.json créé")
    
    # Charger et vérifier
    with open(jobs_dir / "jobs_dataset.json", 'r', encoding='utf-8') as f:
        data = json.load(f)
    
    print(f"   • {data['metadata']['total_jobs']} offres")
    print(f"   • Généré le {data['metadata']['generated_date']}")
    
    # Vérifier la structure
    sample_job = data['jobs'][0]
    required_fields = [
        'job_id', 'title', 'company', 'location', 'type', 
        'experience', 'salary', 'description', 'requirements', 
        'nice_to_have', 'posted_date', 'url'
    ]
    
    missing_fields = [f for f in required_fields if f not in sample_job]
    
    if not missing_fields:
        print("✅ Structure des offres valide")
    else:
        print(f"⚠️  Champs manquants : {missing_fields}")
    
    # Statistiques finales
    print(f"\n📊 RÉSUMÉ FINAL")
    print(f"   • Offres générées : {len(data['jobs'])}")
    print(f"   • Catégories : {len(data['metadata']['categories'])}")
    print(f"   • Prêt pour l'Étape 5 (Matching CV ↔ Offres)")
    
else:
    print("❌ Dataset non créé")
# Out:
# ✅ VÉRIFICATION FINALE
# ...
# ✅ jobs_dataset.json créé
#    • 25 offres
#    • Généré le 2026-01-25 18:21:43
# ✅ Structure des offres valide
#
# 📊 RÉSUMÉ FINAL
#    • Offres générées : 25
#    • Catégories : 5
#    • Prêt pour l'Étape 5 (Matching CV ↔ Offres)
#
# 🎉 Étape 4 terminée avec succès !
# 📝 Prochaine étape : Matching CV ↔ Offres (Notebook 05)
